# %% [markdown]
# # Web scraping of the Algerian MSPRH COVID-19 Dashboard on arcgis.com

# %% [markdown]
# API Reference : [https://developers.arcgis.com/labs/rest/query-a-feature-layer/](https://developers.arcgis.com/labs/rest/query-a-feature-layer/)

# %% [markdown]
# ## URL to fetch

# %%
import requests
import json
import pandas as pd

# %%
# Define the request URL
url_cumul_global  = 'https://services8.arcgis.com/yhz7DEAMzdabE4ro/arcgis/rest/services/COVID_Death_Cumul/FeatureServer/2/query?f=json&where=1%3D1&returnGeometry=false&spatialRel=esriSpatialRelIntersects&outFields=*&orderByFields=Report%20asc&outSR=102100&resultOffset=0&resultRecordCount=1000&cacheHint=true'

# %%
# Send the request
cumul_global_response = requests.get(url_cumul_global)

# %% [markdown]
# ## Check response

# %%
cumul_global_response.ok
# Out:
# True

# %%
# Status code should be 200 (OK)
cumul_global_response.status_code
# Out:
# 200

# %%
cumul_global_response.text

# %%
cumul_global_response.content

# %% [markdown]
# ## Handling json

# %%
# create a python variable from the json
cumul_global = cumul_global_response.json()

# %%
cumul_global.keys()
# Out:
# dict_keys(['objectIdFieldName', 'uniqueIdField', 'globalIdFieldName', 'geometryType', 'spatialReference', 'fields', 'features'])

# %%
print(json.dumps(cumul_global, indent = 4))
# Out:
# {
#     "objectIdFieldName": "OBJECTID",
#     "uniqueIdField": {
#         "name": "OBJECTID",
#         "isSystemMaintained": true
#     },
#     "globalIdFieldName": "GlobalID",
#     "geometryType": "esriGeometryPoint",
#     "spatialReference": {
#         "wkid": 102100,
#         "latestWkid": 3857
#     },
#     "fields": [
#         {
#             "name": "OBJECTID",
#             "type": "esriFieldTypeOID",
#             "alias": "OBJECTID",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "NOM_WILAYA",
#             "type": "esriFieldTypeString",
#             "alias": "NOM_WILAYA",
#             "sqlType": "sqlTypeOther",
#             "length": 30,
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "GlobalID",
#             "type": "esriFieldTypeGlobalID",
#             "alias": "GlobalID",
#             "sqlType": "sqlTypeOther",
#             "length": 38,
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "CreationDate",
#             "type": "esriFieldTypeDate",
#             "alias": "CreationDate",
#             "sqlType": "sqlTypeOther",
#             "length": 8,
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "Creator",
#             "type": "esriFieldTypeString",
#             "alias": "Creator",
#             "sqlType": "sqlTypeOther",
#             "length": 128,
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "EditDate",
#             "type": "esriFieldTypeDate",
#             "alias": "EditDate",
#             "sqlType": "sqlTypeOther",
#             "length": 8,
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "Editor",
#             "type": "esriFieldTypeString",
#             "alias": "Editor",
#             "sqlType": "sqlTypeOther",
#             "length": 128,
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "Report",
#             "type": "esriFieldTypeDate",
#             "alias": "Date de rapport",
#             "sqlType": "sqlTypeOther",
#             "length": 8,
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "Cumul",
#             "type": "esriFieldTypeInteger",
#             "alias": "Cumul\u00e9s",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "Death_cumul",
#             "type": "esriFieldTypeInteger",
#             "alias": "Cumule des d\u00e9c\u00e8s",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "gueris",
#             "type": "esriFieldTypeInteger",
#             "alias": "cumul des gu\u00e9ris",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "an",
#             "type": "esriFieldTypeInteger",
#             "alias": "< 1 an",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "unquatorze",
#             "type": "esriFieldTypeInteger",
#             "alias": "1-14 ans",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "vingtquatre",
#             "type": "esriFieldTypeInteger",
#             "alias": "15-24 ans",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "quaranteneuf",
#             "type": "esriFieldTypeInteger",
#             "alias": "25-49 ans",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "cinquanteneuf",
#             "type": "esriFieldTypeInteger",
#             "alias": "50-59 ans",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "soixante",
#             "type": "esriFieldTypeInteger",
#             "alias": ">60 ans",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "F\u00e9minin",
#             "type": "esriFieldTypeInteger",
#             "alias": "F\u00e9minin",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "Masculin",
#             "type": "esriFieldTypeInteger",
#             "alias": "Masculin",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "Testpositif",
#             "type": "esriFieldTypeInteger",
#             "alias": "Test Positif",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "Testnegatif",
#             "type": "esriFieldTypeInteger",
#             "alias": "Test N\u00e9gatif",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "NP",
#             "type": "esriFieldTypeInteger",
#             "alias": "Age non pr\u00e9cis\u00e9",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "Straitem",
#             "type": "esriFieldTypeInteger",
#             "alias": "Sous traitement",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "Reanim",
#             "type": "esriFieldTypeInteger",
#             "alias": "En r\u00e9animation",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         },
#         {
#             "name": "New_cases",
#             "type": "esriFieldTypeInteger",
#             "alias": "Nouveaux cas",
#             "sqlType": "sqlTypeOther",
#             "domain": null,
#             "defaultValue": null
#         }
#     ],
#     "features": [
#         {
#             "attributes": {
#                 "OBJECTID": 1,
#                 "NOM_WILAYA": "ADRAR",
#                 "GlobalID": "a2c41c84-1e1e-44f9-93fe-b91d0d4c7251",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402155873,
#                 "Editor": "covid19dz",
#                 "Report": 1582660800000,
#                 "Cumul": 1,
#                 "Death_cumul": 0,
#                 "gueris": 0,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": null
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 2,
#                 "NOM_WILAYA": "CHLEF",
#                 "GlobalID": "17b3e898-7574-4ef4-9dd0-d99e0630cba2",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402160320,
#                 "Editor": "covid19dz",
#                 "Report": 1582930800000,
#                 "Cumul": 3,
#                 "Death_cumul": 0,
#                 "gueris": 0,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 2
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 3,
#                 "NOM_WILAYA": "LAGHOUAT",
#                 "GlobalID": "fc47e77a-fc64-41d1-82ad-9b03cf370e0c",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402162904,
#                 "Editor": "covid19dz",
#                 "Report": 1583190000000,
#                 "Cumul": 5,
#                 "Death_cumul": 0,
#                 "gueris": 0,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 3
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 4,
#                 "NOM_WILAYA": "OUM EL BOUAGHI",
#                 "GlobalID": "37d4c6b3-1248-416a-8c83-36595ae22cb3",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402166931,
#                 "Editor": "covid19dz",
#                 "Report": 1583276400000,
#                 "Cumul": 17,
#                 "Death_cumul": 0,
#                 "gueris": 0,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 12
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 5,
#                 "NOM_WILAYA": "BATNA",
#                 "GlobalID": "302927cd-98df-477f-af5d-404a36081c9d",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402174016,
#                 "Editor": "covid19dz",
#                 "Report": 1583535600000,
#                 "Cumul": 19,
#                 "Death_cumul": 0,
#                 "gueris": 0,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 2
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 6,
#                 "NOM_WILAYA": "BEJAIA",
#                 "GlobalID": "0a936d07-a458-45ba-88a4-00bc3b2fd807",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402178179,
#                 "Editor": "covid19dz",
#                 "Report": 1583622000000,
#                 "Cumul": 20,
#                 "Death_cumul": 0,
#                 "gueris": 0,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 1
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 7,
#                 "NOM_WILAYA": "BISKRA",
#                 "GlobalID": "860b3696-3d24-4b75-97d5-c5f3102ca8ad",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585400214304,
#                 "Editor": "covid19dz",
#                 "Report": 1583967600000,
#                 "Cumul": 25,
#                 "Death_cumul": 1,
#                 "gueris": 10,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 5
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 8,
#                 "NOM_WILAYA": "BECHAR",
#                 "GlobalID": "439b9d9d-4693-4ea7-b64d-5b56e36d65cd",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402319811,
#                 "Editor": "covid19dz",
#                 "Report": 1584140400000,
#                 "Cumul": 35,
#                 "Death_cumul": 2,
#                 "gueris": null,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 10
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 9,
#                 "NOM_WILAYA": "BLIDA",
#                 "GlobalID": "22a212ea-3d27-42ad-b149-c1cdb5bd6055",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402316613,
#                 "Editor": "covid19dz",
#                 "Report": 1584216000000,
#                 "Cumul": 52,
#                 "Death_cumul": 4,
#                 "gueris": null,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 7
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 10,
#                 "NOM_WILAYA": "BOUIRA",
#                 "GlobalID": "5c42ce2f-4121-4fe8-b2a6-9e0eac2cb0b3",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402314421,
#                 "Editor": "covid19dz",
#                 "Report": 1584313200000,
#                 "Cumul": 58,
#                 "Death_cumul": 4,
#                 "gueris": null,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 6
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 11,
#                 "NOM_WILAYA": "TAMENGHASSET",
#                 "GlobalID": "2fd575dc-9162-4ab6-985d-e4cda3b64e74",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402312109,
#                 "Editor": "covid19dz",
#                 "Report": 1584399600000,
#                 "Cumul": 60,
#                 "Death_cumul": 5,
#                 "gueris": null,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 2
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 12,
#                 "NOM_WILAYA": "TEBESSA",
#                 "GlobalID": "2d390ad3-c0e0-4a55-a09f-51e2ce5e0aff",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585400104463,
#                 "Editor": "covid19dz",
#                 "Report": 1584486000000,
#                 "Cumul": 72,
#                 "Death_cumul": 6,
#                 "gueris": 22,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 12
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 13,
#                 "NOM_WILAYA": "TLEMCEN",
#                 "GlobalID": "a00b4154-a006-481b-bd47-b23cfcf4fea7",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402267520,
#                 "Editor": "covid19dz",
#                 "Report": 1584572400000,
#                 "Cumul": 90,
#                 "Death_cumul": 8,
#                 "gueris": null,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 18
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 14,
#                 "NOM_WILAYA": "TIARET",
#                 "GlobalID": "c42a89d9-b347-498f-8a03-66059918282b",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402271096,
#                 "Editor": "covid19dz",
#                 "Report": 1584658800000,
#                 "Cumul": 102,
#                 "Death_cumul": 8,
#                 "gueris": null,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 12
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 15,
#                 "NOM_WILAYA": "SIDI BEL ABBES",
#                 "GlobalID": "525566e0-8b96-4fa7-9029-8bf412b83c79",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585400584976,
#                 "Editor": "covid19dz",
#                 "Report": 1584745200000,
#                 "Cumul": 139,
#                 "Death_cumul": 15,
#                 "gueris": 22,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 37
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 16,
#                 "NOM_WILAYA": "ANNABA",
#                 "GlobalID": "1c354592-4a7d-4145-8891-e1c77d2ade50",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585400540828,
#                 "Editor": "covid19dz",
#                 "Report": 1584831600000,
#                 "Cumul": 201,
#                 "Death_cumul": 17,
#                 "gueris": 23,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 62
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 57,
#                 "NOM_WILAYA": null,
#                 "GlobalID": "762329c7-20b2-4194-94db-5a6907b7711b",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585400503208,
#                 "Editor": "covid19dz",
#                 "Report": 1584979200000,
#                 "Cumul": 230,
#                 "Death_cumul": 17,
#                 "gueris": 24,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 29
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 58,
#                 "NOM_WILAYA": null,
#                 "GlobalID": "bbb74ede-6e70-48ce-8c47-89ada712a650",
#                 "CreationDate": 1585127268468,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402293290,
#                 "Editor": "covid19dz",
#                 "Report": 1585065600000,
#                 "Cumul": 264,
#                 "Death_cumul": 19,
#                 "gueris": null,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 34
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 59,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "618bb139-326e-4089-b00f-8deec3ea6bb3",
#                 "CreationDate": 1585159612174,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402299931,
#                 "Editor": "covid19dz",
#                 "Report": 1585123200000,
#                 "Cumul": 302,
#                 "Death_cumul": 21,
#                 "gueris": null,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 38
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 60,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "61f2b45a-0481-45c2-bfc8-76820be4a719",
#                 "CreationDate": 1585238868180,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585402295965,
#                 "Editor": "covid19dz",
#                 "Report": 1585242000000,
#                 "Cumul": 367,
#                 "Death_cumul": 25,
#                 "gueris": null,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 65
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 61,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "27141ced-71a6-44d8-9423-ae3b6f1215d6",
#                 "CreationDate": 1585326873838,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585400679755,
#                 "Editor": "covid19dz",
#                 "Report": 1585328400000,
#                 "Cumul": 409,
#                 "Death_cumul": 26,
#                 "gueris": 29,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 42
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 62,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "c40fb51f-c271-481a-8bb5-10be66f1c2e8",
#                 "CreationDate": 1585411650344,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585427737716,
#                 "Editor": "covid19dz",
#                 "Report": 1585411200000,
#                 "Cumul": 454,
#                 "Death_cumul": 29,
#                 "gueris": 31,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 45
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 63,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "d8adda0f-c24d-451a-9668-62a0367f8d5c",
#                 "CreationDate": 1585499145027,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585499181137,
#                 "Editor": "covid19dz",
#                 "Report": 1585497600000,
#                 "Cumul": 511,
#                 "Death_cumul": 31,
#                 "gueris": 31,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 57
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 64,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "08856503-d95f-4797-9bec-c0cd9c14e150",
#                 "CreationDate": 1585584264830,
#                 "Creator": "covid19dz",
#                 "EditDate": 1585584291911,
#                 "Editor": "covid19dz",
#                 "Report": 1585584000000,
#                 "Cumul": 584,
#                 "Death_cumul": 35,
#                 "gueris": 37,
#                 "an": null,
#                 "unquatorze": null,
#                 "vingtquatre": null,
#                 "quaranteneuf": null,
#                 "cinquanteneuf": null,
#                 "soixante": null,
#                 "F\u00e9minin": null,
#                 "Masculin": null,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 73
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 65,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "e1fe38c8-74da-4f2a-9f2d-2b0bc45bfedb",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1585663200000,
#                 "Cumul": 716,
#                 "Death_cumul": 44,
#                 "gueris": 46,
#                 "an": 1,
#                 "unquatorze": 11,
#                 "vingtquatre": 23,
#                 "quaranteneuf": 274,
#                 "cinquanteneuf": 130,
#                 "soixante": 258,
#                 "F\u00e9minin": 323,
#                 "Masculin": 393,
#                 "Testpositif": 716,
#                 "Testnegatif": 2512,
#                 "NP": null,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 132
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 66,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "38c20aa4-7821-40d8-9b2e-15efef51b63e",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1585695600000,
#                 "Cumul": 847,
#                 "Death_cumul": 58,
#                 "gueris": 61,
#                 "an": 1,
#                 "unquatorze": 12,
#                 "vingtquatre": 27,
#                 "quaranteneuf": 322,
#                 "cinquanteneuf": 150,
#                 "soixante": 311,
#                 "F\u00e9minin": 379,
#                 "Masculin": 467,
#                 "Testpositif": 847,
#                 "Testnegatif": 2381,
#                 "NP": 24,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 131
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 70,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "0511e651-9e5b-4e2d-a0c5-96cabcfe1d7d",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1585782000000,
#                 "Cumul": 986,
#                 "Death_cumul": 63,
#                 "gueris": 61,
#                 "an": 1,
#                 "unquatorze": 13,
#                 "vingtquatre": 31,
#                 "quaranteneuf": 369,
#                 "cinquanteneuf": 177,
#                 "soixante": 366,
#                 "F\u00e9minin": 433,
#                 "Masculin": 553,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 29,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 139
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 71,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "ef64304a-8196-4d98-bc91-7790ff9cedb7",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1585868400000,
#                 "Cumul": 1171,
#                 "Death_cumul": 105,
#                 "gueris": 62,
#                 "an": 1,
#                 "unquatorze": 17,
#                 "vingtquatre": 39,
#                 "quaranteneuf": 424,
#                 "cinquanteneuf": 210,
#                 "soixante": 448,
#                 "F\u00e9minin": 499,
#                 "Masculin": 672,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 32,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 185
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 75,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "5ef57a2c-7af1-4135-a502-9e1edda6eccd",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586016000000,
#                 "Cumul": 1251,
#                 "Death_cumul": 130,
#                 "gueris": 90,
#                 "an": 1,
#                 "unquatorze": 18,
#                 "vingtquatre": 41,
#                 "quaranteneuf": 442,
#                 "cinquanteneuf": 228,
#                 "soixante": 448,
#                 "F\u00e9minin": 530,
#                 "Masculin": 721,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 33,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 80
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 76,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "b6bcb8f3-92d7-46d0-bd27-153f9fd83ea2",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586102400000,
#                 "Cumul": 1320,
#                 "Death_cumul": 152,
#                 "gueris": 90,
#                 "an": 1,
#                 "unquatorze": 19,
#                 "vingtquatre": 42,
#                 "quaranteneuf": 465,
#                 "cinquanteneuf": 239,
#                 "soixante": 519,
#                 "F\u00e9minin": 557,
#                 "Masculin": 763,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 35,
#                 "Straitem": 2890,
#                 "Reanim": null,
#                 "New_cases": 69
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 77,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "dd4288e0-06eb-452e-9010-c008477b6eb1",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586188800000,
#                 "Cumul": 1423,
#                 "Death_cumul": 173,
#                 "gueris": 90,
#                 "an": 1,
#                 "unquatorze": 25,
#                 "vingtquatre": 46,
#                 "quaranteneuf": 502,
#                 "cinquanteneuf": 262,
#                 "soixante": 548,
#                 "F\u00e9minin": 600,
#                 "Masculin": 823,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 39,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 103
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 78,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "105ae142-31e3-4c8f-b1ec-6347d609f3e4",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586275200000,
#                 "Cumul": 1468,
#                 "Death_cumul": 193,
#                 "gueris": 113,
#                 "an": 1,
#                 "unquatorze": 25,
#                 "vingtquatre": 46,
#                 "quaranteneuf": 520,
#                 "cinquanteneuf": 269,
#                 "soixante": 565,
#                 "F\u00e9minin": 613,
#                 "Masculin": 855,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 42,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 45
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 79,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "8fc1c9af-c46b-491f-b560-b35c83b859ef",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586361600000,
#                 "Cumul": 1572,
#                 "Death_cumul": 205,
#                 "gueris": 237,
#                 "an": 1,
#                 "unquatorze": 28,
#                 "vingtquatre": 47,
#                 "quaranteneuf": 555,
#                 "cinquanteneuf": 287,
#                 "soixante": 610,
#                 "F\u00e9minin": 655,
#                 "Masculin": 917,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 44,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 104
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 80,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "715be6e9-2dbc-4f6f-b767-53bd6ec3a41a",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586448000000,
#                 "Cumul": 1666,
#                 "Death_cumul": 235,
#                 "gueris": 347,
#                 "an": 1,
#                 "unquatorze": 30,
#                 "vingtquatre": 48,
#                 "quaranteneuf": 588,
#                 "cinquanteneuf": 309,
#                 "soixante": 643,
#                 "F\u00e9minin": 695,
#                 "Masculin": 971,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 47,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 94
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 81,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "0a34a8c9-ba67-4a9b-addb-2310e8e62726",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586534400000,
#                 "Cumul": 1761,
#                 "Death_cumul": 256,
#                 "gueris": 405,
#                 "an": 1,
#                 "unquatorze": 31,
#                 "vingtquatre": 50,
#                 "quaranteneuf": 617,
#                 "cinquanteneuf": 323,
#                 "soixante": 688,
#                 "F\u00e9minin": 736,
#                 "Masculin": 1025,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 51,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 95
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 82,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "965249e1-098a-4ca7-8783-64dc5393de03",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586620800000,
#                 "Cumul": 1825,
#                 "Death_cumul": 275,
#                 "gueris": 460,
#                 "an": 1,
#                 "unquatorze": 34,
#                 "vingtquatre": 51,
#                 "quaranteneuf": 645,
#                 "cinquanteneuf": 336,
#                 "soixante": 704,
#                 "F\u00e9minin": 761,
#                 "Masculin": 1064,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 54,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 64
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 83,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "2b427a00-0d22-4f72-9b87-98f866410745",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586707200000,
#                 "Cumul": 1914,
#                 "Death_cumul": 293,
#                 "gueris": 591,
#                 "an": 1,
#                 "unquatorze": 38,
#                 "vingtquatre": 54,
#                 "quaranteneuf": 678,
#                 "cinquanteneuf": 350,
#                 "soixante": 737,
#                 "F\u00e9minin": 794,
#                 "Masculin": 1120,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 56,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 89
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 84,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "23a21b10-dbb1-46d9-a2b0-0ecf29d54f8c",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586793600000,
#                 "Cumul": 1983,
#                 "Death_cumul": 313,
#                 "gueris": 601,
#                 "an": 1,
#                 "unquatorze": 38,
#                 "vingtquatre": 60,
#                 "quaranteneuf": 700,
#                 "cinquanteneuf": 636,
#                 "soixante": 763,
#                 "F\u00e9minin": 830,
#                 "Masculin": 1153,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 58,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 69
#             }
#         },
#         {
#             "attributes": {
#                 "OBJECTID": 85,
#                 "NOM_WILAYA": "",
#                 "GlobalID": "c4ae601e-d104-4e61-b575-df7644b71306",
#                 "CreationDate": null,
#                 "Creator": null,
#                 "EditDate": null,
#                 "Editor": null,
#                 "Report": 1586873700000,
#                 "Cumul": 2070,
#                 "Death_cumul": 325,
#                 "gueris": 691,
#                 "an": 1,
#                 "unquatorze": 38,
#                 "vingtquatre": 61,
#                 "quaranteneuf": 735,
#                 "cinquanteneuf": 374,
#                 "soixante": 789,
#                 "F\u00e9minin": 869,
#                 "Masculin": 1201,
#                 "Testpositif": null,
#                 "Testnegatif": null,
#                 "NP": 72,
#                 "Straitem": null,
#                 "Reanim": null,
#                 "New_cases": 87
#             }
#         }
#     ]
# }

# %%
len(cumul_global['features'])
# Out:
# 39

# %%
new_cases = []
new_cases = [(w['attributes']) for w in cumul_global['features']]
new_cases[15]
# Out:
# {'OBJECTID': 16,
#  'NOM_WILAYA': 'ANNABA',
#  'GlobalID': '1c354592-4a7d-4145-8891-e1c77d2ade50',
#  'CreationDate': 1585127268468,
#  'Creator': 'covid19dz',
#  'EditDate': 1585400540828,
#  'Editor': 'covid19dz',
#  'Report': 1584831600000,
#  'Cumul': 201,
#  'Death_cumul': 17,
#  'gueris': 23,
#  'an': None,
#  'unquatorze': None,
#  'vingtquatre': None,
#  'quaranteneuf': None,
#  'cinquanteneuf': None,
#  'soixante': None,
#  'Féminin': None,
#  'Masculin': None,
#  'Testpositif': None,
#  'Testnegatif': None,
#  'NP': None,
#  'Straitem': None,
#  'Reanim': None,
#  'New_cases': 62}

# %%
new_cases[15]['New_cases']
# Out:
# 62

# %% [markdown]
# # URL with params

# %%
base_url  = 'https://services8.arcgis.com/yhz7DEAMzdabE4ro/arcgis/rest/services/COVID_Death_Cumul/FeatureServer/2/query?'
params = {'f' : 'json', 'where' : '1=1', 'returnGeometry' : 'false', 'spatialRel' : 'esriSpatialRelIntersects',
          'outFields' : '*', 'orderByFields' : 'Report asc', 'outSR' : '102100', 'resultOffset' : '0',
          'resultRecordCount' : '1000', 'cacheHint' : 'true'}

# %%
r = requests.get(base_url, params)

# %%
r.status_code
# Out:
# 200

# %%
cumul = r.json()

# %%
len(cumul['features'])
# Out:
# 39

# %%
cumul['features'][15]
# Out:
# {'attributes': {'OBJECTID': 16,
#   'NOM_WILAYA': 'ANNABA',
#   'GlobalID': '1c354592-4a7d-4145-8891-e1c77d2ade50',
#   'CreationDate': 1585127268468,
#   'Creator': 'covid19dz',
#   'EditDate': 1585400540828,
#   'Editor': 'covid19dz',
#   'Report': 1584831600000,
#   'Cumul': 201,
#   'Death_cumul': 17,
#   'gueris': 23,
#   'an': None,
#   'unquatorze': None,
#   'vingtquatre': None,
#   'quaranteneuf': None,
#   'cinquanteneuf': None,
#   'soixante': None,
#   'Féminin': None,
#   'Masculin': None,
#   'Testpositif': None,
#   'Testnegatif': None,
#   'NP': None,
#   'Straitem': None,
#   'Reanim': None,
#   'New_cases': 62}}

# %% [markdown]
# # Importing to Pandas

# %%
print(json.dumps(cumul_global['features'], indent = 4))

# %%
cumul['features'][15]['attributes'].keys()
# Out:
# dict_keys(['OBJECTID', 'NOM_WILAYA', 'GlobalID', 'CreationDate', 'Creator', 'EditDate', 'Editor', 'Report', 'Cumul', 'Death_cumul', 'gueris', 'an', 'unquatorze', 'vingtquatre', 'quaranteneuf', 'cinquanteneuf', 'soixante', 'Féminin', 'Masculin', 'Testpositif', 'Testnegatif', 'NP', 'Straitem', 'Reanim', 'New_cases'])

# %%
attributes = [f['attributes'] for f in cumul['features']]

# %%
df = pd.DataFrame(attributes)

# %%
df.columns.values
# Out:
# array(['OBJECTID', 'NOM_WILAYA', 'GlobalID', 'CreationDate', 'Creator',
#        'EditDate', 'Editor', 'Report', 'Cumul', 'Death_cumul', 'gueris',
#        'an', 'unquatorze', 'vingtquatre', 'quaranteneuf', 'cinquanteneuf',
#        'soixante', 'Féminin', 'Masculin', 'Testpositif', 'Testnegatif',
#        'NP', 'Straitem', 'Reanim', 'New_cases'], dtype=object)

# %%
df.head()
# Out:
#    OBJECTID      NOM_WILAYA                              GlobalID  \
# 0         1           ADRAR  a2c41c84-1e1e-44f9-93fe-b91d0d4c7251
# 1         2           CHLEF  17b3e898-7574-4ef4-9dd0-d99e0630cba2
# 2         3        LAGHOUAT  fc47e77a-fc64-41d1-82ad-9b03cf370e0c
# 3         4  OUM EL BOUAGHI  37d4c6b3-1248-416a-8c83-36595ae22cb3
# 4         5           BATNA  302927cd-98df-477f-af5d-404a36081c9d
#
#    CreationDate    Creator      EditDate     Editor         Report  Cumul  \
# 0  1.585127e+12  covid19dz  1.585402e+12  covid19dz  1582660800000      1
# 1  1.585127e+12  covid19dz  1.585402e+12  covid19dz  1582930800000      3
# 2  1.585127e+12  covid19dz  1.585402e+12  covid19dz  1583190000000      5
# 3  1.585127e+12  covid19dz  1.585402e+12  covid19dz  1583276400000     17
# 4  1.585127e+12  covid19dz  1.585402e+12  covid19dz  1583535600000     19
#
#    Death_cumul  ...  cinquanteneuf  soixante  Féminin  Masculin  Testpositif  \
# 0            0  ...            NaN       NaN      NaN       NaN          NaN
# 1            0  ...            NaN       NaN      NaN       NaN          NaN
# 2            0  ...            NaN       NaN      NaN       NaN          NaN
# 3            0  ...            NaN       NaN      NaN       NaN          NaN
# 4            0  ...            NaN       NaN      NaN       NaN          NaN
#
#    Testnegatif  NP  Straitem  Reanim  New_cases
# 0          NaN NaN       NaN    None        NaN
# 1          NaN NaN       NaN    None        2.0
# 2          NaN NaN       NaN    None        3.0
# 3          NaN NaN       NaN    None       12.0
# 4          NaN NaN       NaN    None        2.0
#
# [5 rows x 25 columns]

# %%
# save the data

# %%
df.to_csv('cumul_covid19-dz.csv', index = False, header = True)

# %% [markdown]
# # POST request

# %%
recipe = {'f' : 'json', 'where' : '1=1', 'returnGeometry' : 'false', 'spatialRel' : 'esriSpatialRelIntersects',
          'outFields' : '*', 'orderByFields' : 'Report asc', 'outSR' : '102100', 'resultOffset' : '0',
          'resultRecordCount' : '1000', 'cacheHint' : 'true'}

# %%
headers = {'Content-Type' : 'application/x-www-form-urlencoded', 
           'Accept' : 'application/x-www-form-urlencoded'}

# %%
p = requests.post(base_url, headers = headers, json = recipe)

# %%
p.status_code
# Out:
# 200

# %%
p.text
